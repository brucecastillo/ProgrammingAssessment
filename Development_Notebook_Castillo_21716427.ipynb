# %% [markdown]
# <a href="https://colab.research.google.com/github/brucecastillo/ProgrammingAssessment/blob/main/Development_Notebook_Castillo_21716427.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cardio Health Analysis
#
# Instruction:
# Create two notebooks in Colab to Analyse Cardio Health.
#
# A. ***Business Report*** : it includes codes, analysis and design  discussion.
#
# B. ***Development Notebook*** :  it includes pseudocode, step-by-step code developement process, testing, and any other industry best practice.

# %% [markdown]
# # Problem Statement:
#
# The formative assignment aims to come up a discussion on Cardio Health analysis with the given database.
#
#  The Cardio Health dataset is in a database file named "cardiohealth.db" which contains information about age, gender, height, weight, ap_hi (systolic blood pressure), ap_lo (diastolic blood pressure), cholesterol, glucose, smoking status, alcohol, physical activity and cardiovascular disease presence.
#
# Main task is to develop a program to analyze dataset in a database file named "cadiohealth.db"
#
# The program should design and visualise the following:
#
# 1. Average rate of cardiovascular disease between genders (Male or Female)
# 2. Explore Blood Pressure (Systolic and Diastolic)
# 3. Analyze Glucose and Blood Pressure
# 4. Study the Connection between Smoking and Physical Activity
#
# This visualization aims to provide the relationship between the occurence of cardiovascular disease and the following factors within the provided cardio health dataset.

# %% [markdown]
# # Algorithm/Pseudocode
# Import sqlite3 since the data set is huge
#
# Read the "cardiohealth.db" file using pandas.
#
# Create a cursor.
#
# Filter Data of:
#
# 1. Average rate of cardiovascular disease between genders
# 2. Explore Blood Pressure (Systolic and Diastolic)
# 3. Analyze Glucose and Blood Pressure
# 4. Study the Connection between Smoking and Physical Activity
#
# Display the tables in the cardiohealth.db
#
# Data Extraction and Initial Exploration
#
# Cleaning and Pre-processing
#
# Data Cleaning and Data checking for 'Inconsistent Values'
#
# Data Manipulation
#
# Grouping and aggregation
#
# Import matplotlib.pyplot to visualise data
#
# Import seaborn : Seaborn is a Python data visualization library based on matplotlib. source: https://seaborn.pydata.org/
#
# Plot the graph for:
#
# 1. Average rate of cardiovascular disease between genders
#
# - Pie Chart for Females and Males
#
# 2. Explore Blood Pressure (Systolic and Diastolic)
# - Bar graph for Systolic and Diastolic
#
# 3. Analyze Glucose and Blood Pressure
# - Bar graph fpr Glucose and Blood Pressure
#
# 4. Study the Connection between Smoking and Physical Activity
# - Bar graph for the connection of Smoking and Physical Activity
#
# Display the graph
#
# Discussion and Conclusion of the programming assignment on Cardio Heatlh.
